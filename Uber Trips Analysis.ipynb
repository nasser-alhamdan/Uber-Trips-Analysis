# %%
# importing the necessary Python libraries and the dataset:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("uber.csv")

# %%
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512
# 3  9/1/2014 0:06:00  40.7450 -73.9889  B02512
# 4  9/1/2014 0:11:00  40.8145 -73.9444  B02512

# %%
df["Date/Time"] = df["Date/Time"].map(pd.to_datetime) 
df.head()
# Out:
#             Date/Time      Lat      Lon    Base
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512

# %%
df["Day"] = df["Date/Time"].apply(lambda x: x.day)
df["Weekday"] = df["Date/Time"].apply(lambda x: x.weekday())
df["Hour"] = df["Date/Time"].apply(lambda x: x.hour)
print(df.head())
# Out:
#             Date/Time      Lat      Lon    Base  Day  Weekday  Hour
# 0 2014-09-01 00:01:00  40.2201 -74.0021  B02512    1        0     0
# 1 2014-09-01 00:01:00  40.7500 -74.0027  B02512    1        0     0
# 2 2014-09-01 00:03:00  40.7559 -73.9864  B02512    1        0     0
# 3 2014-09-01 00:06:00  40.7450 -73.9889  B02512    1        0     0
# 4 2014-09-01 00:11:00  40.8145 -73.9444  B02512    1        0     0

# %%
sns.set(rc={'figure.figsize':(12, 10)})
sns.distplot(df["Day"])
# Out:
# C:\Users\nasse\AppData\Local\Temp\ipykernel_3236\2543991725.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Day"])
# <AxesSubplot: xlabel='Day', ylabel='Density'>

# %%
sns.distplot(df["Hour"])
# Out:
# C:\Users\nasse\AppData\Local\Temp\ipykernel_3236\1297407254.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Hour"])
# <AxesSubplot: xlabel='Hour', ylabel='Density'>

# %%
sns.distplot(df["Weekday"])
# Out:
# C:\Users\nasse\AppData\Local\Temp\ipykernel_3236\711552386.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weekday"])
# <AxesSubplot: xlabel='Weekday', ylabel='Density'>

# %%
# Correlation of Weekday and Hour
df = df.groupby(["Weekday", "Hour"]).apply(lambda x: len(x))
df = df.unstack()
sns.heatmap(df, annot=False)
# Out:
# <AxesSubplot: xlabel='Hour', ylabel='Weekday'>
